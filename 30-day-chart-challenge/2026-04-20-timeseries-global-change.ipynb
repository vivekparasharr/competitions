# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/datasets/global-temp/master/data/monthly.csv"
df = pd.read_csv(url)

# DEBUG: check data
print(df.head())
print(df["Source"].unique())

# Aggregate without filtering
yearly = df.groupby("Year")["Mean"].mean().reset_index()

# Plot
plt.figure(figsize=(12,6))
plt.plot(yearly["Year"], yearly["Mean"])

plt.axhline(0, linestyle="--")
plt.title("Global Temperature Anomaly Over Time")
plt.xlabel("Year")
plt.ylabel("Temperature Anomaly (°C)")
plt.grid(True)

plt.show()
# Out:
#   Source     Year    Mean
# 0   gcag  1850-01 -0.6746
# 1   gcag  1850-02 -0.3334
# 2   gcag  1850-03 -0.5913
# 3   gcag  1850-04 -0.5887
# 4   gcag  1850-05 -0.5088
# ['gcag' 'GISTEMP']
